# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import nltk
import glob
# %matplotlib inline

# %%
import pandas as pd
path1 = "datasets/IMDB dataset/IMDb movies.csv" # use your path
df_imdb_movies = pd.read_csv(path1)

path2 = "datasets/IMDB dataset/IMDb names.csv" # use your path
df_imdb_names = pd.read_csv(path2)

path3 = "datasets/IMDB dataset/IMDb ratings.csv" # use your path
df_imdb_ratings = pd.read_csv(path3)

path4 = "datasets/IMDB dataset/IMDb title_principals.csv" # use your path
df_imdb_titleprincipals = pd.read_csv(path4)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_imdb_movies.head()
# Out:
#   imdb_title_id  ... reviews_from_critics
# 0     tt0000009  ...                  2.0
# 1     tt0000574  ...                  7.0
# 2     tt0001892  ...                  2.0
# 3     tt0002101  ...                  3.0
# 4     tt0002130  ...                 14.0
#
# [5 rows x 22 columns]

# %%
df_imdb_names.head()
# Out:
#   imdb_name_id             name  ... spouses_with_children  children
# 0    nm0000001     Fred Astaire  ...                     1         2
# 1    nm0000002    Lauren Bacall  ...                     2         3
# 2    nm0000003  Brigitte Bardot  ...                     1         1
# 3    nm0000004     John Belushi  ...                     0         0
# 4    nm0000005   Ingmar Bergman  ...                     5         8
#
# [5 rows x 17 columns]

# %%
df_imdb_ratings.head()
# Out:
#   imdb_title_id  ...  non_us_voters_votes
# 0     tt0000009  ...                 70.0
# 1     tt0000574  ...                331.0
# 2     tt0001892  ...                123.0
# 3     tt0002101  ...                105.0
# 4     tt0002130  ...               1166.0
#
# [5 rows x 49 columns]

# %%
df_imdb_titleprincipals.head()
# Out:
#   imdb_title_id  ...                                         characters
# 0     tt0000009  ...           ["Miss Geraldine Holbrook (Miss Jerry)"]
# 1     tt0000009  ...                                   ["Mr. Hamilton"]
# 2     tt0000009  ...  ["Chauncey Depew - the Director of the New Yor...
# 3     tt0000009  ...                                                NaN
# 4     tt0000574  ...                                     ["Kate Kelly"]
#
# [5 rows x 6 columns]

# %%
oscar_2019 = df_imdb_movies.loc[(df_imdb_movies['title'] == "Parasite") & (df_imdb_movies['year'] == '2019')]

oscar_2018 = df_imdb_movies.loc[(df_imdb_movies['title'] == "Green Book") & (df_imdb_movies['year'] == '2018')]

oscar_2017 = df_imdb_movies.loc[(df_imdb_movies['original_title'] == "The Shape of Water")]

oscar_2016 = df_imdb_movies.loc[(df_imdb_movies['title'] == "Moonlight") & (df_imdb_movies['year'] == '2016')]

oscar_2015 = df_imdb_movies.loc[(df_imdb_movies['original_title'] == "Spotlight")]

oscar_2014 = df_imdb_movies.loc[(df_imdb_movies['original_title'] == "Birdman or (The Unexpected Virtue of Ignorance)")]

oscar_2013 = df_imdb_movies.loc[(df_imdb_movies['original_title'] == "12 Years a Slave")]

oscar_2012 = df_imdb_movies.loc[(df_imdb_movies['title'] == "Argo")  & (df_imdb_movies['imdb_title_id'] == 'tt1024648')]

oscar_2011 = df_imdb_movies.loc[(df_imdb_movies['title'] == "The Artist")]

oscar_2010 = df_imdb_movies.loc[(df_imdb_movies['original_title'] == "The King's Speech") ]

oscar_2009 = df_imdb_movies.loc[(df_imdb_movies['original_title'] == "The Hurt Locker") ]

oscar_2008 = df_imdb_movies.loc[(df_imdb_movies['original_title'] == "Slumdog Millionaire") ]

oscar_2007 = df_imdb_movies.loc[(df_imdb_movies['original_title'] == "No Country for Old Men") ]

oscar_2006 = df_imdb_movies.loc[(df_imdb_movies['original_title'] == "The Departed") ]

oscar_2005 = df_imdb_movies.loc[(df_imdb_movies['original_title'] == "Crash") & (df_imdb_movies['year'] == 2004)]

oscar_2004 = df_imdb_movies.loc[(df_imdb_movies['original_title'] == "Million Dollar Baby") & (df_imdb_movies['year'] == 2004)]

oscar_2003 = df_imdb_movies.loc[(df_imdb_movies['original_title'] == "The Lord of the Rings: The Return of the King") ]

oscar_2002 = df_imdb_movies.loc[(df_imdb_movies['title'] == "Chicago") & (df_imdb_movies['year'] == '2002')]

oscar_2001 = df_imdb_movies.loc[(df_imdb_movies['original_title'] == "A Beautiful Mind") ]

oscar_2000 = df_imdb_movies.loc[(df_imdb_movies['original_title'] == "Gladiator") & (df_imdb_movies['year'] == 2000)]

oscar_1999 = df_imdb_movies.loc[(df_imdb_movies['original_title'] == "American Beauty")]

oscar_1998 = df_imdb_movies.loc[(df_imdb_movies['original_title'] == "Shakespeare in Love")]

oscar_1997 = df_imdb_movies.loc[(df_imdb_movies['original_title'] == "Titanic") & (df_imdb_movies['year'] == 1997) ]

oscar_1996 = df_imdb_movies.loc[(df_imdb_movies['original_title'] == "The English Patient")]

oscar_1995 = df_imdb_movies.loc[(df_imdb_movies['original_title'] == "Braveheart") & (df_imdb_movies['year'] == 1995)]

oscar_1994 = df_imdb_movies.loc[(df_imdb_movies['original_title'] == "Forrest Gump")]

oscar_1993 = df_imdb_movies.loc[(df_imdb_movies['original_title'] == "Unforgiven")]

oscar_1992 = df_imdb_movies.loc[(df_imdb_movies['original_title'] == "Schindler's List")]

oscar_1991 = df_imdb_movies.loc[(df_imdb_movies['original_title'] == "The Silence of the Lambs")]

oscar_1990 = df_imdb_movies.loc[(df_imdb_movies['original_title'] == "Dances with Wolves")]


list_oscar = [oscar_2019, oscar_2018, oscar_2017, oscar_2016, oscar_2015, oscar_2014, oscar_2013, oscar_2012, oscar_2011, oscar_2010,
              oscar_2009, oscar_2008, oscar_2007, oscar_2006, oscar_2005, oscar_2004, oscar_2003, oscar_2002, oscar_2001, oscar_2000,
              oscar_1999, oscar_1998, oscar_1997, oscar_1996, oscar_1995, oscar_1994, oscar_1993, oscar_1992, oscar_1991, oscar_1990,]

all_oscar_movies = pd.concat(list_oscar, axis = 0, ignore_index=True)

all_oscar_movies.to_csv("all_oscar_movies.csv")

all_oscar_movies
# Out:
#    imdb_title_id  ... reviews_from_critics
# 0      tt6751668  ...                542.0
# 1      tt6966692  ...                400.0
# 2      tt5580390  ...                999.0
# 3      tt4975722  ...                517.0
# 4      tt1895587  ...                533.0
# 5      tt2562232  ...                628.0
# 6      tt2024544  ...                617.0
# 7      tt1024648  ...                668.0
# 8      tt1655442  ...                585.0
# 9      tt1504320  ...                480.0
# 10     tt0887912  ...                410.0
# 11     tt1010048  ...                418.0
# 12     tt0477348  ...                524.0
# 13     tt0407887  ...                289.0
# 14     tt0375679  ...                295.0
# 15     tt0405159  ...                266.0
# 16     tt0167260  ...                353.0
# 17     tt0268978  ...                152.0
# 18     tt0172495  ...                213.0
# 19     tt0169547  ...                198.0
# 20     tt0138097  ...                130.0
# ...
